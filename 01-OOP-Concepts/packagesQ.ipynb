# %%
import csv

with open('example.csv',mode = 'w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['anurag',21])

with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['anurag', '21']

# %%
import math 
print(math.sqrt(25))
print(math.sin(90))
# Out:
# 5.0
# 0.8939966636005579

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2025-08-26 08:46:21.224181

# %%
import random 
print(random.randint(1,100))
# Out:
# 19

# %%
from math import sqrt,pow

print(sqrt(16))
print(pow(2,3))
# Out:
# 4.0
# 8.0

# %%
import os
new_dir = 'my_new_folder'
os.mkdir(new_dir)

for item in os.listdir():
    print(item)

os.rmdir(new_dir)
# Out:
# example.csv
# my_new_folder
# packagesQ.ipynb

# %%
import math
print(math.gcd(10,100))
print(math.factorial(5))
# Out:
# 10
# 120

# %%
import datetime
today = datetime.datetime.now()
print(today)
future_date = today + datetime.timedelta(100)
print(future_date)
date = dt.date(2025,8,26)
day_of_week = date.strftime('%A')
print(day_of_week)
# Out:
# 2025-08-26 09:10:51.504795
# 2025-12-04 09:10:51.504795
# Tuesday

# %%
import random 
rand_list = random.sample(range(1,51),5)
print(rand_list)

random.shuffle(rand_list)
print(rand_list)
# Out:
# [21, 23, 43, 6, 39]
# [23, 6, 21, 39, 43]

# %%
from packages.module1 import add
from packages.module2 import multiply
print(add(8,2))
multiply(8,2)
# Out:
# 10
# 16
